// %%
const {TextractClient, AnalyzeDocumentCommand, 
       StartDocumentAnalysisCommand, GetDocumentAnalysisCommand} = require("@aws-sdk/client-textract");
const { PutObjectCommand, DeleteObjectCommand, S3Client } = require("@aws-sdk/client-s3");
const _ = require("lodash");
const fuzzysort = require('fuzzysort');
const { readFileSync, writeFileSync } = require ("fs");

// %%
// START of Internal Functions

const uploadFile = async (filePath, s3Client) => {
    // function to upload a file specified in the filepath to 
    // the ocr-scanning-invoices bucket
    // Returns the file name of the file uploaded onto the s3 bucket
    
    const fileContent = readFileSync(filePath);
    // extract filename from the filepath to upload onto the bucket
    // add the current datetime so that uploaded files will be unique,
    // even if the filename is the same
    const key = new Date().getTime() + '_' + filePath.match(/[^\\/]+$/)[0];
    
    const bucketParams = { Bucket: "ocr-scanning-storage", Key: key
                            , Body:fileContent};
    
    const command = new PutObjectCommand(bucketParams);
    
    try {
    console.log('uploading ' + key);
    const response = await s3Client.send(command);
    //console.log(response);
    console.log('uploaded ' + key);
  } catch (err) {
    console.log('error');
    console.error(err);
    return null
  }
    
    return key
}

const deleteFile = async (key, s3Client = null) => {
//deleteFile = async (key, s3Client) => {

    // function to delete a file with the given key name in the `ocr-scanning-storage` bucket

    
    const bucketParams = { Bucket: "ocr-scanning-storage", Key: key };
      
    try {
        const data = await s3Client.send(new DeleteObjectCommand(bucketParams));
        console.log("Success. Object deleted.");
        return data; // For unit tests.
    } catch (err) {
        console.log("Error", err);
        return null
    }
}


// Async textract analysis

const wait = (msec) => new Promise((resolve, _) => {
    // use this function to wait for the try loop
  setTimeout(resolve, msec);
});

async function getAsyncAnalysis(key, textractClient) {   

    // Initialise params, create command object
    const params = {
    DocumentLocation: {

      "S3Object":{
            "Bucket":"ocr-scanning-storage",
            //"Name":"test.jpg"
            "Name":key
      } 
    },
    FeatureTypes: ["FORMS", "TABLES"]
    //FeatureTypes: ["TABLES"]
  };
    
    const startCommand = new StartDocumentAnalysisCommand(params);
    

    // run StartDocumentAnalysis
    const startCommandResult = await textractClient.send(startCommand);
    const jobid = startCommandResult.JobId; // read the jobid so we can read the results later
    // console.log(startCommandResult)
    
    // initialise params and command for GetDocumentAnalysis
    const getCommand = new GetDocumentAnalysisCommand( { "JobId": jobid} );
    
    // run loop to check for GetDocumentAnalysis
    var finished = false;
    var data;
    
    while (!finished) {
        // set timer for the while loop
        await wait(1500);
        
        // keep checking if the job has completed
//         console.log('checking if the job is finished...')
        data =  await textractClient.send(getCommand);
        if (data.JobStatus !== "IN_PROGRESS") {
            // when the analysis is done, break out of the loop'
            finished = true;
        }
    }
    
    
    // check if the analysis failed:
    if (data.JobStatus === "FAILED") {
        console.log("WTFFFFFF BROOOO THE ANALYSIS FAILED");
        return (null);
    }
    
    
    // return json file
//     console.log('writing to file....')
//      writeFileSync('file.json', JSON.stringify(data, null, 2), (error) => {
//          if (error) throw error;
//      });
    
    return data;

}


// END of Internal Functions

// %%
const getTextractAnalysis = async (filepath) => { // #### EXPORT this function
    // function to get the textract raw json data
    // This function does 3 things
    // 1. Upload file onto the `ocr-scanning-invoices` bucket
    // 2. Run textract analysis on the uploaded file
    // 3. Delete the file in the bucket
    
    // set up clients to be used
    const s3Client = new S3Client();
    const textractClient = new TextractClient();
    
    // upload to bucket
    const key = await uploadFile(filepath, s3Client);
    console.log('uploaded ' + key);
    
    // textract analysis
    const data = await getAsyncAnalysis(key, textractClient)
    console.log('analysis done')
    
    // delete the file
    await deleteFile(key, s3Client);
    console.log('deleted the file');
    
    return data;
    
    
}

// %%
// START of Form Parser
const getText = (result, blocksMap) => {
  let text = "";

  if (_.has(result, "Relationships")) {
    result.Relationships.forEach(relationship => {
      if (relationship.Type === "CHILD") {
        relationship.Ids.forEach(childId => {
          const word = blocksMap[childId];
          if (word.BlockType === "WORD") {
            text += `${word.Text} `;
          }
          if (word.BlockType === "SELECTION_ELEMENT") {
            if (word.SelectionStatus === "SELECTED") {
              text += `X `;
            }
          }
        });
      }
    });
  }

  return text.trim();
};

const findValueBlock = (keyBlock, valueMap) => {
  let valueBlock;
  keyBlock.Relationships.forEach(relationship => {
    if (relationship.Type === "VALUE") {
      // eslint-disable-next-line array-callback-return
      relationship.Ids.every(valueId => {
        if (_.has(valueMap, valueId)) {
          valueBlock = valueMap[valueId];
          return false;
        }
      });
    }
  });

  return valueBlock;
};

const getKeyValueRelationship = (keyMap, valueMap, blockMap) => {
  const keyValues = {};

  const keyMapValues = _.values(keyMap);

  keyMapValues.forEach(keyMapValue => {
    const valueBlock = findValueBlock(keyMapValue, valueMap);
    //const key = getText(keyMapValue, blockMap); // do a bit of extra cleaning first
    const key = getText(keyMapValue, blockMap).toLowerCase().replace(/\W*$/, "");
    const value = getText(valueBlock, blockMap);
    keyValues[key] = value;
  });

  return keyValues;
};

const getKeyValueMap = blocks => {
  const keyMap = {};
  const valueMap = {};
  const blockMap = {};

  let blockId;
  blocks.forEach(block => {
    blockId = block.Id;
    blockMap[blockId] = block;

    if (block.BlockType === "KEY_VALUE_SET") {
      if (_.includes(block.EntityTypes, "KEY")) {
        keyMap[blockId] = block;
      } else {
        valueMap[blockId] = block;
      }
    }
  });

  return { keyMap, valueMap, blockMap };
};



const fixFormHeaders = (obj, dict) => {
    // autocorrect and match the keys in obj to the values of dict
    currentHeaders = Object.keys(obj);
    correctHeaders = Object.keys(dict.mapping); // autocorrect to these values
    headerList = [...dict.headers]; // list of headers we want in the output
    outobj = {}; // result
    
    maxLength = 0; // record the maximum length of the lists
                   // in the object, so we can fill up space later 

    for (const header of currentHeaders) {
        // do an autocorrect; get the 'nearest' correct header
        searchRes = fuzzysort.go(header, correctHeaders)

        // if there is a result, take the first one,
        // then put it in the new object
        if (searchRes.length > 0) {
            corrected = dict.mapping[searchRes[0].target];
            // this is the header for the output object
            
            // remove the header that we found from the list
            // of correct headers
            
            if (! (corrected in outobj)) {
                // if the header is NOT in the output object...
                // remove it from the list of headers
                headerList.splice(headerList.indexOf(corrected), 1);
                // and add it to the output object
                outobj[corrected] = obj[header];
            }
            
            // see if the length is greater than the maximum
            if (obj[header].length > maxLength) {
                maxLength = obj[header].length;
            } 
        }
    }
    
    // after getting the headers that we have into the 
    // output, time to clean it up
    
    // fill missing headers with blanks
    if (headerList.length > 0) {
        for (const header of headerList) {
            // fill missing headers with empty strings
            outobj[header] = '';
            
        }
    }
    
    return outobj;
}

const extractForms = (data, dict) => { // #### EXPORT this function
    // takes in raw textract response, and dictionary mapping for required fields
    if (data && data.Blocks) {
        const {keyMap, valueMap, blockMap} = getKeyValueMap(data.Blocks);
        const keyValues = getKeyValueRelationship(keyMap, valueMap, blockMap);
        const fixedKeyValues = fixFormHeaders(keyValues, dict);
        return fixedKeyValues;
    };

    return undefined; 
    // if no key-values are found, return undefined, then deal with it later
}

// END of Form Parser

// %%
// START of Table Parser

const getTableResults = (data) => {

    blocks=data['Blocks'];
    
    blocks_map = {};
    table_blocks = [];
    
    // make blocks_map, and list down which blocks are table
    for (const block of blocks) {
        id = block['Id'];
        blocks_map[id] = block;
        
        if (block['BlockType'] === "TABLE") {
            table_blocks.push(block);
        }
    }
    
    // check if there are no tables
    if (table_blocks.length <= 0) {
        console.log('No tables found!!!!');
        return [];
    }
    
    csv = []
    for (const table of table_blocks) {
        // for each table found, add an entry into the `csv` array
        //csv.push( generateTableCsv( table, blocks_map, i+1 ) );
        csv.push( getRowsColumnsMap(table, blocks_map) );
        
    }
    
    
    return csv
}


const getRowsColumnsMap = (table_result, blocks_map) => {
    cols = {};
    headers = [];
    for (const relationship of table_result['Relationships']) {
        if (relationship['Type'] === 'CHILD') {
            for (const child_id of relationship['Ids']) {
                cell = blocks_map[child_id];
                if (cell['BlockType'] === 'CELL') {
                    row_index = parseInt(cell['RowIndex']) - 1;
                    col_index = parseInt(cell['ColumnIndex']) - 1;

                    if (! (col_index in cols) ) {

                        // create new column
                        cols[col_index] = [];
                    }
                    // get the text value
                    text = getText(cell, blocks_map);
                    //rows[col_index][row_index] = text;
                    if (row_index === 0) {
                        headers[col_index] = text.toLowerCase().replace(/\W*$/, ""); 
                        // if row index is 0, it is a header so store it for processing later
                    } else {

                        cols[col_index][row_index-1] = text;
                    }
                }
            }
        }
    }
    
    output_table = {}; // This is the final output
    for (col_index in headers) {
        // given the column index, assign the header to the column in the new object
        output_table[headers[col_index]] = cols[col_index];
    } 
//     return rows;
    return output_table;
}

const mergeTables = (obj1, obj2) => { // function to merge objects based on header names
    // objects must have only arrays as values
    // assume that obj1's keys are absolutely correct
    const keys = Object.keys(obj1);
    var out = {};
    for (const key of keys) {
         out[key] = Array.prototype.concat(obj1[key], obj2[key]);
    }
    return out;
}


const fixTableHeaders = (obj, dict) => {
    // autocorrect and match the keys in obj to the values of dict
    currentHeaders = Object.keys(obj);
    correctHeaders = Object.keys(dict.mapping); // autocorrect to these values
    headerList = [...dict.headers]; // list of headers we want in the output
    outobj = {}; // result
    
    maxLength = 0; // record the maximum length of the lists
                   // in the object, so we can fill up space later 

    for (const header of currentHeaders) {
        // do an autocorrect; get the 'nearest' correct header
        searchRes = fuzzysort.go(header, correctHeaders)

        // if there is a result, take the first one,
        // then put it in the new object
        if (searchRes.length > 0) {
            corrected = dict.mapping[searchRes[0].target];
            // this is the header for the output object
            
            // remove the header that we found from the list
            // of correct headers
            
            if (! (corrected in outobj)) {
                // if the header is NOT in the output object...
                // remove it from the list of headers
                headerList.splice(headerList.indexOf(corrected), 1);
                // and add it to the output object
                outobj[corrected] = obj[header];
            }
            
            // see if the length is greater than the maximum
            if (obj[header].length > maxLength) {
                maxLength = obj[header].length;
            } 
        }
    }
    // after getting the headers that we have into the 
    // output, time to clean it up
    
    // make sure that all lengths are the same
    // idt we'll ever have to use this but good to have i think
    for (const header of Object.keys(outobj)) {
        if (outobj[header].length < maxLength) {
            // fill up with extra spaces
            extra = Array(maxLength - outobj[header].length).fill('');
            outobj[header] = outobj[header].concat(extra);
        }
    }
    // if there are empty headers, fill them up with empty slots
    if (headerList.length > 0) {
        for (const header of headerList) {
            // fill missing headers with empty strings
            outobj[header] = Array(maxLength).fill('');
        }
    }
    return outobj;
}


const extractTables = (data, dict) => { // #### EXPORT this function
    // do the normal extract tables
    // for each table obtained, fix the headers
    // then merge the fixed header tables
    if (data && data.Blocks) {
        // do the normal extract tables
        const tables = getTableResults(data); // this is a list of table objects with dirty header names
        // for each table obtained, fix the headers
        // then merge the fixed header tables
        var outputTable = {}; // this is the output table
        const headers = dict.headers;
        for (const header of headers) { // populate it with the headers we want first so we can easily concatenate
            outputTable[header] = [];
        }
        
        for (const table of tables) { // for each table we obtained, clean the headers and merge it
            const fixedTable = fixTableHeaders(table, dict);
            outputTable = mergeTables(outputTable, fixedTable)
        }
    }
    return outputTable;
}


// END of Table Parser
// Out:
// [Function: mergeTables]

// %%
s3Client = new S3Client();
textractClient = new TextractClient();
async function hi(){//b = await uploadFile('test.jpg', s3Client);
//     b =  await getAsyncAnalysis('pdf1.pdf', textractClient);
    b = await getTextractAnalysis('test.jpg')
                   return b}

b = hi()
console.log(b)
// Out:
// uploading 1689599188734_test.jpg
// Promise { <pending> }
// uploaded 1689599188734_test.jpg
// uploaded 1689599188734_test.jpg
// analysis done
// Success. Object deleted.
// deleted the file

// %%
// a = deleteFile('1689559372548_test.jpg', s3Client)
formDict = {
    headers:['date', 'grand total', 'gst', 'invoice number'],
    mapping:{'date':'date',
            
            'grand total':'grand total',
            
            'gst':'gst',
            
            'no':'invoice number'}
}
extractForms(b, formDict)
// Out:
// {
//   date: '19.06.2020',
//   'grand total': '104.03',
//   'invoice number': '8157048692',
//   gst: '@ 7%'
// }

// %%
b
// Out:
// {
//   '$metadata': {
//     httpStatusCode: 200,
//     requestId: 'e05d6e2f-c768-4399-9a3d-b0fcf830a5af',
//     extendedRequestId: undefined,
//     cfId: undefined,
//     attempts: 1,
//     totalRetryDelay: 0
//   },
//   AnalyzeDocumentModelVersion: '1.0',
//   Blocks: [
//     {
//       BlockType: 'PAGE',
//       Geometry: [Object],
//       Id: 'd2f8397c-9c2a-4cc9-825b-55940a709074',
//       Page: 1,
//       Relationships: [Array]
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 34.454246520996094,
//       Geometry: [Object],
//       Id: '00a58e6a-7f70-4365-929c-1821da14b198',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Website:www.tipex.com.org'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 78.94392395019531,
//       Geometry: [Object],
//       Id: 'ce50406d-d1b4-4039-a384-c4d59e583cd5',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'TIPE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 91.9151840209961,
//       Geometry: [Object],
//       Id: '1caa025c-a283-4e45-aa75-8f6a3e935827',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'TIPEX PTE.LTD'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 97.02947235107422,
//       Geometry: [Object],
//       Id: '363eabb6-84b4-44aa-a2fe-7a688f9ee42e',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'A Subsidiary of Hanwell Holdings Ltd.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 93.17121124267578,
//       Geometry: [Object],
//       Id: '79b16730-068f-455c-bae8-321b1b3487b0',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'GST Reg No M2-0067173-2'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.73545837402344,
//       Geometry: [Object],
//       Id: '621f4950-7725-41fd-8bdc-51b3c87b6863',
//       Page: 1,
//       Relationships: [Array],
//       Text: '348 Jalan Boon Lay'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 87.82453918457031,
//       Geometry: [Object],
//       Id: 'a712bff9-00cc-4b67-af00-c9ab3097c52b',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Choices for beTTer lives'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.7464828491211,
//       Geometry: [Object],
//       Id: '93ad4332-90e2-44f5-8e8c-0acf98234a2a',
//       Page: 1,
//       Relationships: [Array],
//       Text: '619529 Singapore Singapore'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 96.24320983886719,
//       Geometry: [Object],
//       Id: '3ed99a6b-32fc-4f97-9aee-6156f66231d9',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Tel:62687600 Fax: 62661286'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.91688537597656,
//       Geometry: [Object],
//       Id: '8f4bf3b2-82ef-4d24-afef-31965ed16935',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'BILL TO: 63100001'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.31462097167969,
//       Geometry: [Object],
//       Id: 'cae1dca0-1d0f-4369-aa28-c7423b78ca5d',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'DELIVER TO:'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 93.31471252441406,
//       Geometry: [Object],
//       Id: '07147116-3700-49b8-a7d9-a4b9099b649a',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'DELIVERY ROUTE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 78.48310852050781,
//       Geometry: [Object],
//       Id: '2664a787-8e50-4d35-a647-58a95f455c3d',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'NO'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 90.91106414794922,
//       Geometry: [Object],
//       Id: '6a238ae2-4601-4b2a-9be7-650f1cdc8721',
//       Page: 1,
//       Relationships: [Array],
//       Text: ':'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.3239974975586,
//       Geometry: [Object],
//       Id: 'fd476546-9aab-41a5-9907-33362bf49934',
//       Page: 1,
//       Relationships: [Array],
//       Text: '8157048692'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.27723693847656,
//       Geometry: [Object],
//       Id: '7b894828-0c89-458c-b4be-da035ec896e3',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'KIM ENG MINI SUPERMARKET'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.76292419433594,
//       Geometry: [Object],
//       Id: 'ae7945bf-6da0-4a14-a647-5d186ab0c187',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'KIM ENG MINI SUPERMARKET'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.94369506835938,
//       Geometry: [Object],
//       Id: '591c4b1d-b929-455b-a9f3-c1449bc4c410',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'DATE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 86.6701431274414,
//       Geometry: [Object],
//       Id: 'f9b63fce-9f84-41c6-a1ea-eafe94d0f120',
//       Page: 1,
//       Relationships: [Array],
//       Text: ':'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.5901107788086,
//       Geometry: [Object],
//       Id: 'b1e9d600-1c35-491c-827f-b9dfb5c06e12',
//       Page: 1,
//       Relationships: [Array],
//       Text: '19.06.2020'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.83091735839844,
//       Geometry: [Object],
//       Id: '6ff7eacd-8d84-459f-ab83-77944172ac94',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'BLK 103 YISHUN RING ROAD'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.73016357421875,
//       Geometry: [Object],
//       Id: '9c899df3-199f-4a3e-acbb-c91888ec2118',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'BLK 103 YISHUN RING ROAD'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.21361541748047,
//       Geometry: [Object],
//       Id: '9ad072e3-ab1c-4718-ab99-2956c651cd42',
//       Page: 1,
//       Relationships: [Array],
//       Text: '#01-79'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.48217010498047,
//       Geometry: [Object],
//       Id: '725511d4-0900-4275-80b1-96a5c54fc60d',
//       Page: 1,
//       Relationships: [Array],
//       Text: '#01-79'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.9463882446289,
//       Geometry: [Object],
//       Id: 'c8f1cfa0-47c2-4e31-a544-214c2fb752a5',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'CURRENCY'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 89.04047393798828,
//       Geometry: [Object],
//       Id: '5a40e5bb-09cc-4861-af80-b91e46bcacb1',
//       Page: 1,
//       Relationships: [Array],
//       Text: ':'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.83816528320312,
//       Geometry: [Object],
//       Id: '68f4b0af-9401-4f4b-baff-fb62c8875f1c',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'SGD'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.81043243408203,
//       Geometry: [Object],
//       Id: 'bc052c57-5145-4a86-a9a1-ef08584a3a2d',
//       Page: 1,
//       Relationships: [Array],
//       Text: '760103 SINGAPORE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.88532257080078,
//       Geometry: [Object],
//       Id: 'a0ab9d6c-cd6b-45c1-94b5-7656356088f8',
//       Page: 1,
//       Relationships: [Array],
//       Text: '760103 SINGAPORE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.89521789550781,
//       Geometry: [Object],
//       Id: '5c1b9d99-1b20-4795-96e2-ac7bc7641b7d',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'SINGAPORE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.90676879882812,
//       Geometry: [Object],
//       Id: '41098fdb-6a61-4bf4-abc6-969c39a6c510',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'SINGAPORE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.80577850341797,
//       Geometry: [Object],
//       Id: '3392858b-1a98-476f-a8c9-e9f0b0aecd5f',
//       Page: 1,
//       Relationships: [Array],
//       Text: "COLLECTION'S COPY"
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.17742919921875,
//       Geometry: [Object],
//       Id: 'c9f94e7d-0d95-4476-94f0-ed2d3e77aceb',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'CUSTOMER NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.44639587402344,
//       Geometry: [Object],
//       Id: 'f4057ec8-713d-492a-a02e-50c3fa4ef756',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'PURCHASE ORDER NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 97.76490020751953,
//       Geometry: [Object],
//       Id: 'ffd170c2-de68-4093-9d4d-055bfabfbe74',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'OUR REF. NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.11685943603516,
//       Geometry: [Object],
//       Id: '7967d999-1a9e-4fe4-9acf-97ce9e33567f',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'ORDER NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.92462158203125,
//       Geometry: [Object],
//       Id: '466ead50-14d2-4e5d-9196-89f20dfd36e2',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'SALESMAN'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.93505859375,
//       Geometry: [Object],
//       Id: '2afc066c-b536-4fc7-8e6b-9e90147f0f3f',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'PAYMENT TERM'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.86323547363281,
//       Geometry: [Object],
//       Id: '1b7ca23c-a90e-4d27-87f8-17938d916b7d',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'ITINERARY'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.91555786132812,
//       Geometry: [Object],
//       Id: '7c83c1ab-a786-4507-a6e5-78411a0317ee',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'PAGE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.881591796875,
//       Geometry: [Object],
//       Id: 'df72f47b-022c-4a3e-8948-dfe176501e60',
//       Page: 1,
//       Relationships: [Array],
//       Text: '63100001'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.25457000732422,
//       Geometry: [Object],
//       Id: '149b62f7-7f66-4a30-94b6-d918496f9166',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'S0315800'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.75850677490234,
//       Geometry: [Object],
//       Id: '66cd7d88-09cb-4b36-a343-44fc5e5e8cf2',
//       Page: 1,
//       Relationships: [Array],
//       Text: '5050049651'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.73546600341797,
//       Geometry: [Object],
//       Id: 'df7dd8ec-9278-474e-af26-760ee16a4783',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'PHILIP NEO'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.65174865722656,
//       Geometry: [Object],
//       Id: 'ffcc977b-e70d-4968-a272-4f2c2edd19f6',
//       Page: 1,
//       Relationships: [Array],
//       Text: '30 days'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.65589904785156,
//       Geometry: [Object],
//       Id: '1be90234-1848-49ed-a7f8-bd205733782f',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1 of 1'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.82162475585938,
//       Geometry: [Object],
//       Id: 'caf49274-83aa-467b-803c-aaaf3caf3643',
//       Page: 1,
//       Relationships: [Array],
//       Text: '83884864'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.47059631347656,
//       Geometry: [Object],
//       Id: 'd6c6890e-edca-4eed-9a59-8a1ce7872eed',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.27723693847656,
//       Geometry: [Object],
//       Id: '985a1ff6-f904-48b2-872f-f3e2ad44fe25',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'ITEM NO.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.90039825439453,
//       Geometry: [Object],
//       Id: 'd761ba3d-db9f-4835-963c-79e628853a81',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'ITEM DESCRIPTION'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.92235565185547,
//       Geometry: [Object],
//       Id: '285ec36e-9210-4ae2-bce4-6869a060b015',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'QUANTITY'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 93.66998291015625,
//       Geometry: [Object],
//       Id: '1a60fdc3-406f-4c93-8c37-dd692ceae45a',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'CONV.'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.93763732910156,
//       Geometry: [Object],
//       Id: '342421be-b7e4-46fd-ba47-8d1506a217be',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'UNIT PRICE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.90159606933594,
//       Geometry: [Object],
//       Id: '62bdf919-a4df-4d94-8f02-65e8544d13e2',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'TOTAL DISC AMOUNT'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.92845153808594,
//       Geometry: [Object],
//       Id: '1a591f5c-ae1b-4e40-aa35-8ae9a702d720',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'TOTAL AMOUNT'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.44508361816406,
//       Geometry: [Object],
//       Id: 'b3f737a9-190a-48b8-ab6b-9f1d80d7b04c',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.85366821289062,
//       Geometry: [Object],
//       Id: 'f513a94b-0708-4308-9b1a-0d45876cac0d',
//       Page: 1,
//       Relationships: [Array],
//       Text: '809610001'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 95.35265350341797,
//       Geometry: [Object],
//       Id: 'b305c9bb-db8e-4a91-8451-09d7c982980a',
//       Page: 1,
//       Relationships: [Array],
//       Text: "EYE MO MOIST 7.5ML 12 X 12'S"
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.9568862915039,
//       Geometry: [Object],
//       Id: 'd80133e5-02b5-48d3-889f-6e19e2d792d1',
//       Page: 1,
//       Relationships: [Array],
//       Text: '12'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.90251922607422,
//       Geometry: [Object],
//       Id: '5771ad26-4c2d-4b67-a80e-8b33d47673f7',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'EA'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.72274780273438,
//       Geometry: [Object],
//       Id: 'c8c2caf6-9d87-48cd-aa44-d9156f71cb96',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.86573028564453,
//       Geometry: [Object],
//       Id: '2970b707-c0dd-4109-ae9d-897fc2989f1f',
//       Page: 1,
//       Relationships: [Array],
//       Text: '4.41'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 97.42504119873047,
//       Geometry: [Object],
//       Id: '4cccfdda-ff64-405d-ba85-4369fe6fd9ab',
//       Page: 1,
//       Relationships: [Array],
//       Text: '52.92'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.92982482910156,
//       Geometry: [Object],
//       Id: 'c8229bbc-9af6-4985-96cc-31eeeb3fc368',
//       Page: 1,
//       Relationships: [Array],
//       Text: '2'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.83129119873047,
//       Geometry: [Object],
//       Id: 'f9192991-a705-4b7e-8a3e-79bc433370fb',
//       Page: 1,
//       Relationships: [Array],
//       Text: '809610001'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 96.46048736572266,
//       Geometry: [Object],
//       Id: '079ae70b-6776-4bb9-83e4-b83722e8c869',
//       Page: 1,
//       Relationships: [Array],
//       Text: "EYE MO MOIST 7.5ML 12 X 12'S"
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.6426010131836,
//       Geometry: [Object],
//       Id: '670e0564-a52a-49ee-93a9-73129e867bfa',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.862548828125,
//       Geometry: [Object],
//       Id: 'f1155d46-2092-4dd0-98ec-caa3fb76433d',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'EA'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.81623840332031,
//       Geometry: [Object],
//       Id: '7e3bb143-917c-4428-a2bc-fb8dedae60ab',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.92198181152344,
//       Geometry: [Object],
//       Id: '2a7a5331-e2c8-4239-b3ca-4820fdb495bd',
//       Page: 1,
//       Relationships: [Array],
//       Text: '0.00'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.89703369140625,
//       Geometry: [Object],
//       Id: '88ae467a-276a-4aa4-923b-959fc22d7de5',
//       Page: 1,
//       Relationships: [Array],
//       Text: '0.00'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.9045639038086,
//       Geometry: [Object],
//       Id: 'bfc7ad12-10ac-491a-8e2a-cb0299d1c961',
//       Page: 1,
//       Relationships: [Array],
//       Text: '3'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.58063507080078,
//       Geometry: [Object],
//       Id: 'ba4ccea9-9082-4737-983b-dfe0a99c6e74',
//       Page: 1,
//       Relationships: [Array],
//       Text: '889632002'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 95.0842056274414,
//       Geometry: [Object],
//       Id: '5b5441b9-6146-4060-befd-64a2b3232675',
//       Page: 1,
//       Relationships: [Array],
//       Text: "WETTY ANTIBACTERIAL WIPES 48 X 30'S"
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.78694152832031,
//       Geometry: [Object],
//       Id: 'cc71cc3e-2201-425c-af8d-76758fd7bbcb',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1 CTN'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.95573425292969,
//       Geometry: [Object],
//       Id: '141e1ea1-4d75-4cf4-863f-457e2dc3fcd8',
//       Page: 1,
//       Relationships: [Array],
//       Text: '48'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.94856262207031,
//       Geometry: [Object],
//       Id: 'b9eb8128-b884-456e-b66e-782d1c323c27',
//       Page: 1,
//       Relationships: [Array],
//       Text: '43.20'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.65189361572266,
//       Geometry: [Object],
//       Id: '7f80e5f4-f527-48bb-85dc-ce067f60def6',
//       Page: 1,
//       Relationships: [Array],
//       Text: '43.20'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.90304565429688,
//       Geometry: [Object],
//       Id: '81f86a51-69e5-4729-95e1-6b47e5bcab37',
//       Page: 1,
//       Relationships: [Array],
//       Text: '4'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.60198211669922,
//       Geometry: [Object],
//       Id: 'cadc5372-0d67-4b6f-86ee-7175d4dbfbb9',
//       Page: 1,
//       Relationships: [Array],
//       Text: '888602501'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 96.62918090820312,
//       Geometry: [Object],
//       Id: '7c8276da-c711-4495-b1a0-86863808a274',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'JRT ROLLS (G) 16(4X4)X550G'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.63380432128906,
//       Geometry: [Object],
//       Id: '21b6acbd-e41d-4a6a-9b3d-e8a99999a986',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1 BDL'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.95356750488281,
//       Geometry: [Object],
//       Id: 'd2969ef4-7843-4a6d-997c-b407490f0c1b',
//       Page: 1,
//       Relationships: [Array],
//       Text: '16'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.86154174804688,
//       Geometry: [Object],
//       Id: '2bbac407-98b3-45a6-a5ce-4fc44f8a06a8',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1.06'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.96190643310547,
//       Geometry: [Object],
//       Id: '1bcb97f6-6a81-4364-9918-7ebc0390382d',
//       Page: 1,
//       Relationships: [Array],
//       Text: '0.00'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.9268569946289,
//       Geometry: [Object],
//       Id: 'a6a9c256-ae3a-4174-808d-37a6e71e6093',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'All payment to TIPEX PTE. LTD Bank Account Details: United Overseas Bank Ltd A/C No.: 942-340-627-1 (UOVBSGSG)'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 53.301239013671875,
//       Geometry: [Object],
//       Id: 'c482fe27-f566-4415-be02-50ddadf22d44',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'memecon'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 96.06356811523438,
//       Geometry: [Object],
//       Id: '2bae5972-e905-4937-9e0f-da55811e3213',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Delivery Number: 5200116286'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 6.060852527618408,
//       Geometry: [Object],
//       Id: '524ad928-2161-47d9-9536-4998b946707a',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'TATE'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 97.39707946777344,
//       Geometry: [Object],
//       Id: '1b89efbb-06b4-46a7-9fe5-b1c53c06225f',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Blk'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 98.98477172851562,
//       Geometry: [Object],
//       Id: 'aba710f3-11fa-4de2-beae-301cb4957ae0',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Kim Eng Mini Supermarket'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 82.17520141601562,
//       Geometry: [Object],
//       Id: '7fe00f1b-2564-428f-b71c-6001e9544970',
//       Page: 1,
//       Relationships: [Array],
//       Text: '103 Yishun Ring Road #01-79 Singapore 700 103'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.94619750976562,
//       Geometry: [Object],
//       Id: 'eb3ad3cd-2fc1-4693-88e9-a488fa756c11',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Terms and Condition'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.60554504394531,
//       Geometry: [Object],
//       Id: 'e87d9f2d-e799-4e56-83bd-8e7e2dbe784f',
//       Page: 1,
//       Relationships: [Array],
//       Text: '1. Please verify all entries in this invoice within 7 days from the date of this invoice failing which it shall deem to'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.9306640625,
//       Geometry: [Object],
//       Id: 'af556c76-5966-49c3-8cb7-988c2cca9da5',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'be'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 96.51300048828125,
//       Geometry: [Object],
//       Id: '4dd8eb02-7657-460a-8cc8-884aa5a7536c',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Fax: 67578108'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 71.61664581298828,
//       Geometry: [Object],
//       Id: 'f1b7941a-7c11-445f-af20-f0ad61c1dabd',
//       Page: 1,
//       Relationships: [Array],
//       Text: '6753 5888(Office)'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 97.28445434570312,
//       Geometry: [Object],
//       Id: '6c2e5b7f-0881-4b19-aded-565afd5e28ae',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'correct in all aspects and the goods received in good condition and binding on you'
//     },
//     {
//       BlockType: 'LINE',
//       Confidence: 99.911865234375,
//       Geometry: [Object],
//       Id: 'c4aff79f-d8b3-4915-a876-d36453665bd8',
//       Page: 1,
//       Relationships: [Array],
//       Text: 'Sub-total'
//     },
//     ... 530 more items
//   ],
//   DocumentMetadata: { Pages: 1 },
//   JobStatus: 'SUCCEEDED'
// }

// %%
tableDict = {
    headers:['item number', 'item description', 'unit price', 'amount'],
    mapping:{
        'item no':'item number',
        
        'item description':'item description',
        
        'unit price':'unit price',
        
        'total amount':'amount'
    }
}

extractTables(b, tableDict)
// getTableResults(b, tableDict)
// Out:
// {
//   'item number': [ '1', '2', '3', '4', '', '' ],
//   'item description': [
//     "EYE MO MOIST 7.5ML 12 X 12'S",
//     "EYE MO MOIST 7.5ML 12 X 12'S",
//     "WETTY ANTIBACTERIAL WIPES 48 X 30'S",
//     'JRT ROLLS (G) 16(4X4)X550G',
//     '',
//     'Ltd A/C No.: 942-340-627-1'
//   ],
//   'unit price': [ '4.41', '0.00', '43.20', '1.06', '', '' ],
//   amount: [ '52.92', '0.00', '43.20', '0.00', '', '' ]
// }

// %%
mergeTables = (obj1, obj2) => {
    const keys = Object.keys(obj1);
    var out = {};
    for (const key of keys) {
         out[key] = Array.prototype.concat(obj1[key], obj2[key]);
    }
    return out;
}
a = {'a':[1,2], 'b':[], 'c':['a','s']}
b = {'a':[3, 4], 'b':['arst','rsat',',rast,'], 'c':['a','s',2]}
c = {'a':[], 'b':[], 'c':[]}

mergeTables(a, c)
// Out:
// { a: [ 1, 2 ], b: [], c: [ 'a', 's' ] }

// %%
Array(0)
// Out:
// []
